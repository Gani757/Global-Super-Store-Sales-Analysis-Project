# %%
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\91709\OneDrive\Pictures\Desktop\Financial Sample.xlsx")
df
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera           NaN
# 1          Government                   Germany  Carretera           NaN
# 2           Midmarket                    France  Carretera           NaN
# 3           Midmarket                   Germany  Carretera           NaN
# 4           Midmarket                    Mexico  Carretera           NaN
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %% [markdown]
# ## step 1: Data Exploration

# %%
df.head()
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera           NaN      1618.5
# 1  Government  Germany  Carretera           NaN      1321.0
# 2   Midmarket   France  Carretera           NaN      2178.0
# 3   Midmarket  Germany  Carretera           NaN       888.0
# 4   Midmarket   Mexico  Carretera           NaN      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3          20      32370.0        0.0  32370.0  16185.0
# 1                    3          20      26420.0        0.0  26420.0  13210.0
# 2                    3          15      32670.0        0.0  32670.0  21780.0
# 3                    3          15      13320.0        0.0  13320.0   8880.0
# 4                    3          15      37050.0        0.0  37050.0  24700.0
#
#     Profit       Date  Month Number Month Name  Year
# 0  16185.0 2014-01-01             1    January  2014
# ...

# %%
df.shape        # to check rows & columns
# Out:
# (700, 16)

# %%
df.describe()          # statistical summaries
# Out:
#         Units Sold  Manufacturing Price  Sale Price   Gross Sales  \
# count   700.000000           700.000000  700.000000  7.000000e+02
# mean   1608.294286            96.477143  118.428571  1.827594e+05
# min     200.000000             3.000000    7.000000  1.799000e+03
# 25%     905.000000             5.000000   12.000000  1.739175e+04
# 50%    1542.500000            10.000000   20.000000  3.798000e+04
# 75%    2229.125000           250.000000  300.000000  2.790250e+05
# max    4492.500000           260.000000  350.000000  1.207500e+06
# std     867.427859           108.602612  136.775515  2.542623e+05
#
#            Discounts         Sales           COGS         Profit  \
# count     700.000000  7.000000e+02     700.000000     700.000000
# mean    13150.354629  1.696091e+05  145475.211429   24133.860371
# min         0.000000  1.655080e+03     918.000000  -40617.500000
# 25%       800.320000  1.592800e+04    7490.000000    2805.960000
# ...

# %%
df.info()   # summary of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Segment              700 non-null    object
#  1   Country              700 non-null    object
#  2   Product              700 non-null    object
#  3   Discount Band        647 non-null    object
#  4   Units Sold           700 non-null    float64
#  5   Manufacturing Price  700 non-null    int64
#  6   Sale Price           700 non-null    int64
#  7   Gross Sales          700 non-null    float64
#  8   Discounts            700 non-null    float64
#  9    Sales               700 non-null    float64
#  10  COGS                 700 non-null    float64
#  11  Profit               700 non-null    float64
#  12  Date                 700 non-null    datetime64[ns]
#  13  Month Number         700 non-null    int64
#  14  Month Name           700 non-null    object
# ...

# %%
df.columns=df.columns.str.strip().str.title()
df.columns     # column names
# Out:
# Index(['Segment', 'Country', 'Product', 'Discount Band', 'Units Sold',
#        'Manufacturing Price', 'Sale Price', 'Gross Sales', 'Discounts',
#        'Sales', 'Cogs', 'Profit', 'Date', 'Month Number', 'Month Name',
#        'Year'],
#       dtype='object')

# %% [markdown]
# ## step 2: data cleaning

# %%
# check missing values

df.isnull().sum()
# Out:
# Segment                 0
# Country                 0
# Product                 0
# Discount Band          53
# Units Sold              0
# Manufacturing Price     0
# Sale Price              0
# Gross Sales             0
# Discounts               0
# Sales                   0
# Cogs                    0
# Profit                  0
# Date                    0
# Month Number            0
# Month Name              0
# Year                    0
# dtype: int64

# %%
df.info()   # summary of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Segment              700 non-null    object
#  1   Country              700 non-null    object
#  2   Product              700 non-null    object
#  3   Discount Band        647 non-null    object
#  4   Units Sold           700 non-null    float64
#  5   Manufacturing Price  700 non-null    int64
#  6   Sale Price           700 non-null    int64
#  7   Gross Sales          700 non-null    float64
#  8   Discounts            700 non-null    float64
#  9   Sales                700 non-null    float64
#  10  Cogs                 700 non-null    float64
#  11  Profit               700 non-null    float64
#  12  Date                 700 non-null    datetime64[ns]
#  13  Month Number         700 non-null    int64
#  14  Month Name           700 non-null    object
# ...

# %%
# rename multiple column names

df=df.rename(columns={"Manufacturing Price":"Manufacturing Cost","Discounts":"Discount"})
df
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera           NaN
# 1          Government                   Germany  Carretera           NaN
# 2           Midmarket                    France  Carretera           NaN
# 3           Midmarket                   Germany  Carretera           NaN
# 4           Midmarket                    Mexico  Carretera           NaN
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Cost  Sale Price  Gross Sales   Discount  \
# ...

# %%
# removed unwanted columns 

df=df.drop(['Month Number', 'Month Name','Year'],axis=1)    # axis=1 --column wise
df
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera           NaN
# 1          Government                   Germany  Carretera           NaN
# 2           Midmarket                    France  Carretera           NaN
# 3           Midmarket                   Germany  Carretera           NaN
# 4           Midmarket                    Mexico  Carretera           NaN
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Cost  Sale Price  Gross Sales   Discount  \
# ...

# %%
# treated missing values

df["Discount Band"]=df["Discount Band"].fillna(df["Discount Band"].mode()[0])   # fill with mode()[0] ---index[0]
df.isnull().sum()
# Out:
# Segment               0
# Country               0
# Product               0
# Discount Band         0
# Units Sold            0
# Manufacturing Cost    0
# Sale Price            0
# Gross Sales           0
# Discount              0
# Sales                 0
# Cogs                  0
# Profit                0
# Date                  0
# dtype: int64

# %%
# check for wrong data 

df['Segment'].unique()      # unique values in the column
# Out:
# array(['Government', 'Midmarket', 'Channel Partners', 'Enterprise',
#        'Small Business'], dtype=object)

# %%
df['Segment'].value_counts()    # count of unique values in the column ---discrete
# Out:
# Segment
# Government          300
# Midmarket           100
# Channel Partners    100
# Enterprise          100
# Small Business      100
# Name: count, dtype: int64

# %%
df['Country'].unique()
# Out:
# array(['Canada', 'Germany', 'France', 'Mexico',
#        'United States of America'], dtype=object)

# %%
df['Country'].value_counts()
# Out:
# Country
# Canada                      140
# Germany                     140
# France                      140
# Mexico                      140
# United States of America    140
# Name: count, dtype: int64

# %%
df['Product'].unique()
# Out:
# array(['Carretera', 'Montana', 'Paseo', 'Velo', 'VTT', 'Amarilla'],
#       dtype=object)

# %%
df['Product'].value_counts()
# Out:
# Product
# Paseo        202
# Velo         109
# VTT          109
# Amarilla      94
# Carretera     93
# Montana       93
# Name: count, dtype: int64

# %%
df['Discount Band'].unique()
# Out:
# array(['High', 'Low', 'Medium'], dtype=object)

# %%
df['Discount Band'].value_counts()
# Out:
# Discount Band
# High      298
# Medium    242
# Low       160
# Name: count, dtype: int64

# %%
df['Units Sold'].unique()
# Out:
# array([1618.5, 1321. , 2178. ,  888. , 2470. , 1513. ,  921. , 2518. ,
#        1899. , 1545. , 2665.5,  958. , 2146. ,  345. ,  615. ,  292. ,
#         974. , 1006. ,  367. ,  883. ,  549. ,  788. , 2472. , 1143. ,
#        1725. ,  912. , 2152. , 1817. , 1493. , 1804. , 2161. , 2821. ,
#        2001. , 2838. , 1527. , 2151. , 2750. , 1953. , 4219.5, 1686. ,
#        2141. , 3945. , 2296. , 1030. ,  639. , 1326. , 1858. , 1210. ,
#        2529. , 1445. ,  330. , 2671. ,  766. ,  494. , 1397. , 2155. ,
#        2214. , 2301. , 1375.5, 1830. , 2498. ,  663. , 1514. , 4492.5,
#         727. ,  787. , 1823. ,  747. , 2905. , 3864. ,  362. ,  923. ,
#        2092. ,  263. ,  943.5,  986. , 1744. , 1989. ,  321. ,  742.5,
#        1295. ,  214. , 2145. , 2852. , 1142. , 1566. ,  690. , 1660. ,
#        2363. ,  918. , 1728. ,  662. ,  809. , 1785. , 1916. , 2729. ,
#        1925. , 2013. , 1055. , 1084. , 2966. , 2877. ,  544. ,  266. ,
# ...

# %%
df['Units Sold'].nunique()  # no. of unique values
# Out:
# 510

# %%
df["Manufacturing Cost"].unique()
# Out:
# array([  3,   5,  10, 120, 250, 260], dtype=int64)

# %%
df["Manufacturing Cost"].value_counts()
# Out:
# Manufacturing Cost
# 10     202
# 120    109
# 250    109
# 260     94
# 3       93
# 5       93
# Name: count, dtype: int64

# %%
df['Sale Price'].unique()
# Out:
# array([ 20,  15, 350,  12, 125, 300,   7], dtype=int64)

# %%
df['Sale Price'].value_counts()
# Out:
# Sale Price
# 20     100
# 15     100
# 350    100
# 12     100
# 125    100
# 300    100
# 7      100
# Name: count, dtype: int64

# %%
df['Gross Sales'].nunique()
# Out:
# 550

# %%
df['Discount'].nunique()
# Out:
# 515

# %%
df['Sales'].nunique()
# Out:
# 559

# %%
df['Cogs'].nunique()
# Out:
# 545

# %%
df['Profit'].unique()
# Out:
# array([ 16185.   ,  13210.   ,  10890.   ,   4440.   ,  12350.   ,
#        136170.   ,   4605.   ,  22662.   ,  18990.   ,  13905.   ,
#         13327.5  ,  47900.   ,   4292.   ,   1725.   ,   3075.   ,
#          2920.   ,   4870.   ,  90540.   ,   3303.   ,   1766.   ,
#          2745.   ,  39400.   ,  12360.   ,   2286.   , 155250.   ,
#          8208.   ,  10760.   ,  18170.   ,   2986.   ,   9020.   ,
#         19449.   ,  14105.   , 100050.   ,  25542.   , 137430.   ,
#        107550.   , 247500.   ,  17577.   ,  21097.5  ,   3372.   ,
#         19269.   ,   7613.85 ,  11135.6  ,   1987.9  ,   1233.27 ,
#          2559.18 ,  16499.04 , 104665.   ,   4880.97 ,  12831.6  ,
#          1237.5  ,  23718.48 ,   6802.08 ,  23218.   , 120840.5  ,
#        186407.5  ,  10737.9  , 108147.   ,  13479.9  ,   3531.9  ,
#        117406.   ,   2486.25 ,   7342.9  ,   8670.525,   2726.25 ,
#          2951.25 ,   6836.25 ,   3622.95 , 136535.   ,  37867.2  ,
# ...

# %%
df['Profit'].nunique()
# Out:
# 557

# %%
# check for duplicates records

df.duplicated().sum()
# Out:
# 0

# %%
# Handle unrealistic values in the profit column--Negative values and discount col---zeroes(remove -ve & zeroes) \
# Log of 0 is undefined → must remove zeros

df=df[df['Profit']>0]       # original dataframe=dataframe[continion true]
df=df[df["Discount"]>0]   
df
# Out:
#               Segment                   Country   Product Discount Band  \
# 53         Government                    France     Paseo           Low
# 54          Midmarket                    France     Paseo           Low
# 55         Government                    France     Paseo           Low
# 56         Government                    France      Velo           Low
# 57         Government                    Canada       VTT           Low
# ..                ...                       ...       ...           ...
# 695    Small Business                    France  Amarilla          High
# 696    Small Business                    Mexico  Amarilla          High
# 697        Government                    Mexico   Montana          High
# 698        Government                    Canada     Paseo          High
# 699  Channel Partners  United States of America       VTT          High
#
#      Units Sold  Manufacturing Cost  Sale Price  Gross Sales   Discount  \
# ...

# %%
continuous =['Units Sold', 'Gross Sales', 'Discount', 'Sales', 'Cogs', 'Profit']
discrete =['Segment', 'Country', 'Product', 'Discount Band']
count=['Manufacturing Cost', 'Sale Price']

# %%
#check for outliers
plt.figure(figsize=(10,5))
sns.boxplot(df[continuous])
plt.show()

# %%
#handling outlier using IQR 
for i in continuous:
    Q1=df[i].quantile(0.25)
    Q3=df[i].quantile(0.75)
    IQR=Q3-Q1
    ll=Q1-(1.5*IQR)
    ul=Q3+(1.5*IQR)
    outliers = df[(df[i] < ll) | (df[i] > ul)]
    print(f"Outliers in column '{i}':")
    print(outliers[i].reset_index(drop=True))
    df=df[(df[i] > ll) & (df[i] < ul)].reset_index(drop=True)   # removed outliers stored in df
# Out:
# Outliers in column 'Units Sold':
# 0    4492.5
# 1    4243.5
# 2    4251.0
# Name: Units Sold, dtype: float64
# Outliers in column 'Gross Sales':
# 0      754250.0
# 1      690300.0
# 2      749400.0
# 3      871500.0
# 4      754250.0
# 5      998200.0
# 6      998200.0
# 7     1038100.0
# 8     1006950.0
# 9     1006950.0
# 10     679000.0
# 11    1038100.0
# 12     730350.0
# 13     853200.0
# 14     875400.0
# 15    1207500.0
# 16     761950.0
# 17     761950.0
# 18     652750.0
# 19     667450.0
# 20     726600.0
# 21     730800.0
# 22     726600.0
# 23     654300.0
# 24     654300.0
# 25     824100.0
# 26    1006600.0
# 27     738000.0
# 28     751100.0
# 29     738000.0
# 30    1140750.0
# 31     769500.0
# 32     845950.0
# 33    1138050.0
# 34     797700.0
# 35     724850.0
# 36     809550.0
# 37     688200.0
# 38     982450.0
# 39     688200.0
# 40     654500.0
# 41     784000.0
# 42     897900.0
# 43     843300.0
# 44     736575.0
# 45    1048500.0
# 46     645000.0
# ...

# %%
# outliers are removed

df
# Out:
#               Segment                   Country  Product Discount Band  \
# 0          Government                    France    Paseo           Low
# 1           Midmarket                    France    Paseo           Low
# 2          Government                    France    Paseo           Low
# 3          Government                    France     Velo           Low
# 4          Government                    Canada      VTT           Low
# ..                ...                       ...      ...           ...
# 349         Midmarket                   Germany      VTT          High
# 350        Government                    France      VTT          High
# 351        Government                    Mexico  Montana          High
# 352        Government                    Canada    Paseo          High
# 353  Channel Partners  United States of America      VTT          High
#
#      Units Sold  Manufacturing Cost  Sale Price  Gross Sales  Discount  \
# ...

# %%
# check normality

df[continuous].skew()     # right skewed
# Out:
# Units Sold     0.121671
# Gross Sales    0.759933
# Discount       1.391602
# Sales          0.730978
# Cogs           0.787608
# Profit         0.818447
# dtype: float64

# %% [markdown]
# # Business KPIs & Summary Metrics

# %%
# total sales

df["Sales"].sum()
# Out:
# 6837470.785

# %%
# total Profit

df["Profit"].sum()
# Out:
# 2946803.785

# %%
# statistical summary

df.describe()
# Out:
#         Units Sold  Manufacturing Cost  Sale Price   Gross Sales     Discount  \
# count   354.000000          354.000000  354.000000    354.000000   354.000000
# mean   1578.399718           91.502825   13.460452  21059.737288  1744.848065
# min     218.000000            3.000000    7.000000   1799.000000    18.410000
# 25%     920.750000            5.000000    7.000000  10486.000000   594.615000
# 50%    1561.500000           10.000000   12.000000  18936.000000  1309.280000
# 75%    2249.750000          250.000000   20.000000  29422.500000  2464.640000
# max    3945.000000          260.000000   20.000000  59860.000000  7221.200000
# std     808.642089          107.185953    4.794930  13224.944958  1531.806642
#
#               Sales          Cogs        Profit                           Date
# count    354.000000    354.000000    354.000000                            354
# mean   19314.889223  10990.584746   8324.304477  2014-04-27 05:33:33.559322112
# ...

# %%
# Top 5 Products by Sales and Profit

e=df.groupby("Product")[["Sales","Profit"]].sum().reset_index()
e=e.sort_values(by=["Sales","Profit"]).reset_index(drop=True)   
e.head()
# Out:
#      Product      Sales     Profit
# 0       Velo  875784.19  371015.19
# 1   Amarilla  876580.16  381756.66
# 2    Montana  938011.13  402328.13
# 3  Carretera  951900.76  434972.76
# 4        VTT  979041.12  444357.12

# %%
# Top 3 Countries: Segmented by High Profitability

ff=df.groupby(["Country","Segment"])[["Sales","Profit"]].sum().reset_index()
top3=ff.sort_values(by="Profit",ascending=False).head(3).reset_index(drop=True)
top3
# Out:
#                     Country     Segment       Sales      Profit
# 0                    France  Government  735459.270  284391.770
# 1  United States of America  Government  695946.585  278124.085
# 2                    Mexico  Government  730389.880  276329.880

# %% [markdown]
# ## step 3: data visualization

# %%
for i in continuous:
    sns.histplot(df[i],kde=True)
    plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(df[continuous])
plt.show()

# %%
sns.scatterplot(data=df,x="Discount",y="Sales",hue="Discount Band")
plt.show()

# %% [markdown]
# ### Insight: As the discount increases, sales also increases

# %%
sns.scatterplot(data=df,x="Sales",y="Profit",hue="Discount Band")
plt.show()

# %%
ss=df[["Sales","Profit"]].corr()
ss
# Out:
#            Sales    Profit
# Sales   1.000000  0.817545
# Profit  0.817545  1.000000

# %% [markdown]
# ###  Insight: as the off diagonal is 0.8 strong correlation. so as the sales increases, profits also increase

# %%
cc=df[continuous].corr()
cc
# Out:
#              Units Sold  Gross Sales  Discount     Sales      Cogs    Profit
# Units Sold     1.000000     0.769022  0.585427  0.767638  0.719239  0.572888
# Gross Sales    0.769022     1.000000  0.772658  0.996755  0.882321  0.805861
# Discount       0.585427     0.772658  1.000000  0.719051  0.695973  0.509885
# Sales          0.767638     0.996755  0.719051  1.000000  0.877652  0.817545
# Cogs           0.719239     0.882321  0.695973  0.877652  1.000000  0.441510
# Profit         0.572888     0.805861  0.509885  0.817545  0.441510  1.000000

# %% [markdown]
# ### Insight: as the off diagonal is 0.7 strong correlation. so as the discount increases the sales also increases and profit has less affect

# %%
co=df[continuous].cov()
co
# Out:
#                Units Sold   Gross Sales      Discount         Sales  \
# Units Sold   6.539020e+05  8.224113e+06  7.251583e+05  7.498954e+06
# Gross Sales  8.224113e+06  1.748992e+08  1.565256e+07  1.592466e+08
# Discount     7.251583e+05  1.565256e+07  2.346432e+06  1.330613e+07
# Sales        7.498954e+06  1.592466e+08  1.330613e+07  1.459405e+08
# Cogs         4.509430e+06  9.047167e+07  8.265870e+06  8.220580e+07
# Profit       2.989525e+06  6.877494e+07  5.040258e+06  6.373469e+07
#
#                      Cogs        Profit
# Units Sold   4.509430e+06  2.989525e+06
# Gross Sales  9.047167e+07  6.877494e+07
# Discount     8.265870e+06  5.040258e+06
# Sales        8.220580e+07  6.373469e+07
# Cogs         6.011515e+07  2.209065e+07
# Profit       2.209065e+07  4.164404e+07

# %%
 #  >2 Discrete variables

pd.crosstab([df["Product"],df["Country"]],df["Discount Band"],margins=True)
# Out:
# Discount Band                       High  Low  Medium  All
# Product   Country
# Amarilla  Canada                       3    0       4    7
#           France                       6    2       2   10
#           Germany                      3    0       5    8
#           Mexico                       6    0       5   11
#           United States of America     4    3       2    9
# Carretera Canada                       4    5       4   13
#           France                       2    2       4    8
#           Germany                      3    2       4    9
#           Mexico                       2    0       6    8
#           United States of America     4    3       4   11
# Montana   Canada                       4    3       4   11
#           France                       2    3       5   10
#           Germany                      1    1       4    6
#           Mexico                       8    3       1   12
#           United States of America     4    2       2    8
# ...

# %% [markdown]
# ### Insight: Paseo has the highest discount in all countries

# %%
df["Date"]=pd.to_datetime(df["Date"],errors="coerce")   # converted date to datetime format

df["yearmonth"]=df["Date"].dt.to_period("M")


monthly_data=df.groupby("yearmonth")[["Sales","Profit"]].sum().reset_index()

# convert yearmonth to timestamp for plotting 
monthly_data["yearmonth"]=monthly_data["yearmonth"].dt.to_timestamp() 


# stacked line plot --monthly trend showing sales + profit

plt.figure(figsize=(10, 5))
plt.plot(monthly_data["yearmonth"], monthly_data["Sales"],marker="s",label="sales")
plt.plot(monthly_data["yearmonth"], monthly_data["Profit"],marker="s",label="profit")
plt.legend()
plt.title("Monthly sales")
plt.xlabel("month")
plt.ylabel("sales")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Insight:
# Focus on increasing profit efficiency during high-sales months (optimize discounts or reduce costs).
#
# Consider targeted campaigns in Q4, as sales historically spike during that period.
#
# Investigate mid-year performance dip to identify root causes and fix gaps.

# %%
sns.jointplot(data=df,x="Sales",y="Profit",kind='scatter',hue="Discount Band",space=0.2)
plt.tight_layout()
plt.show()

# %%
sns.pairplot(df,x_vars="Sales",y_vars="Profit",hue="Discount Band",height=4)

plt.show()

# %%
sns.heatmap(cc,annot=True)
plt.show()

# %% [markdown]
# ### Insight:
#
# Sales and COGS are highly correlated (0.88) → High COGS when Sales are high.
#
# Gross Sales and Profit also show strong correlation (0.81).
#
# Discount and Profit correlation is weaker (0.51) → Higher discount doesn’t strongly impact profit.
#
# Units Sold and Gross Sales correlation is 0.77 → expected in sales-driven businesses.

# %%
for i in discrete:
    sns.countplot(x=df[i])
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# ### Insight: count of each Discrete variable

# %%
d=df.groupby("Segment")[["Sales","Profit"]].sum().reset_index()
d
# Out:
#             Segment        Sales       Profit
# 0  Channel Partners  1497598.560  1091941.560
# 1        Government  3455607.775  1345197.775
# 2         Midmarket  1884264.450   509664.450

# %%
plt.figure(figsize=(6,5))
sns.barplot(data=d,x="Segment",y="Sales",label="Sales")
sns.barplot(data=d,x="Segment",y="Profit",label="Profit")
plt.title("Stacked Bar Plot: Sales + Profit by Segment")
plt.legend()
plt.show()

# %% [markdown]
# ### Insight: sales and profit are high for Government Segment compared to others

# %%
plt.pie(d["Sales"],labels=d["Segment"],autopct="%1.1f%%",explode=[0,0.1,0])
plt.title("Sales percentage by segment")
plt.show()

# %% [markdown]
# ### Insight: Sales percentage of Government segment is 50.5%

# %%
plt.pie(d["Profit"], labels=d["Segment"],autopct="%1.1f%%",explode=[0,0.1,0])
plt.title("Profit percentage by segment")
plt.show()

# %% [markdown]
# ### Insight: Profit percentage of Government segment is 45.6%

# %%
e=df.groupby("Product")[["Sales","Profit"]].sum().reset_index()
e=e.sort_values(by=["Sales","Profit"]).reset_index(drop=True)   
e
# Out:
#      Product        Sales      Profit
# 0       Velo   875784.190  371015.190
# 1   Amarilla   876580.160  381756.660
# 2    Montana   938011.130  402328.130
# 3  Carretera   951900.760  434972.760
# 4        VTT   979041.120  444357.120
# 5      Paseo  2216153.425  912373.925

# %%
plt.figure(figsize=(6,5))
sns.barplot(data=e,x="Product",y="Sales",label="Sales")
sns.barplot(data=e,x="Product",y="Profit",label="Profit")
plt.title("Stacked Bar Plot: Sales + Profit by Product")
plt.legend()
plt.show()

# %% [markdown]
# ### Insight:  Paseo Dominates in Overall Revenue
#
# Focus marketing and sales resources on Paseo—clearly a high ROI product.
#
# Analyze why other products have lower profit —consider reviewing manufacturing or discount strategies.
#
# Explore cross-selling lower performers with Paseo for bundling opportunities.

# %%
plt.pie(e["Sales"],labels=e["Product"],autopct="%0.1f%%",explode=[0,0,0,0.1,0,0])
plt.title("Sales percentage by Product")
plt.show()

# %% [markdown]
# ### Insight: sales percentage of paeso product is 32.4%

# %%
plt.pie(e["Profit"],labels=e["Product"],autopct="%0.1f%%",explode=[0,0,0,0.1,0,0])
plt.title("Profit percentage by Product")
plt.show()

# %% [markdown]
# ### Insight: Profit percentage of paeso product is 31.0%

# %%
ee=df.groupby(["Product","Segment"])[["Sales","Profit"]].sum().reset_index()
ee
# Out:
#       Product           Segment        Sales      Profit
# 0    Amarilla  Channel Partners   230493.600  165762.600
# 1    Amarilla        Government   406626.110  155463.610
# 2    Amarilla         Midmarket   239460.450   60530.450
# 3   Carretera  Channel Partners   282838.680  208405.680
# 4   Carretera        Government   414797.080  160142.080
# 5   Carretera         Midmarket   254265.000   66425.000
# 6     Montana  Channel Partners   213088.560  155890.560
# 7     Montana        Government   494773.520  182588.520
# 8     Montana         Midmarket   230149.050   63849.050
# 9       Paseo  Channel Partners   365952.720  266745.720
# 10      Paseo        Government  1138434.205  446621.705
# 11      Paseo         Midmarket   711766.500  199006.500
# 12        VTT  Channel Partners   266772.960  194223.960
# 13        VTT        Government   475975.710  186740.710
# 14        VTT         Midmarket   236292.450   63392.450
# ...

# %%
# unstacked bar plot


plt.figure(figsize=(8,6))
sns.barplot(data=ee,x="Product",y="Sales",hue="Segment")
plt.title("Unstacked Bar Plot: Sales by Product and Segment")
plt.legend()
plt.show()

# %%
# unstacked bar plot


plt.figure(figsize=(8,6))
sns.barplot(data=ee,x="Product",y="Profit",hue="Segment")
plt.title("Unstacked Bar Plot: Profit by Product and Segment")
plt.legend()
plt.show()

# %% [markdown]
# ### insight:
# Promote and bundle Paseo more aggressively—it’s clearly the most profitable product across all segments.
#
# Consider discounting or incentives for Midmarket buyers to improve profit contributions.
#
# Dive deeper into why Velo performs well in Government—can the same strategy apply to other products?

# %%
ff=df.groupby(["Country","Segment"])[["Sales","Profit"]].sum().reset_index()
ff
# Out:
#                      Country           Segment       Sales      Profit
# 0                     Canada  Channel Partners  349713.060  255274.560
# 1                     Canada        Government  632954.600  243624.600
# 2                     Canada         Midmarket  477933.975  121728.975
# 3                     France  Channel Partners  372090.360  271581.360
# 4                     France        Government  735459.270  284391.770
# 5                     France         Midmarket  363322.200   99842.200
# 6                    Germany  Channel Partners  234953.880  171254.880
# 7                    Germany        Government  660857.440  262727.440
# 8                    Germany         Midmarket  260889.750   71869.750
# 9                     Mexico  Channel Partners  234379.080  170890.080
# 10                    Mexico        Government  730389.880  276329.880
# 11                    Mexico         Midmarket  385346.400  108616.400
# ...

# %%
plt.figure(figsize=(8,6))
sns.barplot(data=ff,x="Country",y="Sales",hue="Segment")

plt.title("Unstacked Bar Plot: Revenue by Country and Segment")
plt.legend()
plt.show()

# %% [markdown]
# ### insight:
#
# Focus on retaining and expanding Government contracts in all countries.
#
# Explore Channel Partner strategies in countries like Germany and Mexico to increase penetration.
#
# The USA market may benefit from customized offerings for Midmarket and Channel Partners.

# %% [markdown]
# # Overall Insights
#
# 1) Sales & Profit Trend:
#
# Sales and Profit showed noticeable ***monthly fluctuations***, with peaks observed around ***Oct–Nov 2013 and Oct–Nov 2014.***
#
# Despite sales rising, profit margins remained lower, indicating potential discount-driven or high-cost sales.
#
# 2) Top Performing Countries:
#
# ***United States, Mexico, and France*** generated the highest overall sales and profit.
#
# However, the ***Government segment consistently outperformed*** others across countries in terms of profit.
#
# 3) Product Performance:
#
# ***Paseo*** emerged as the best-selling and ***most profitable product***, far ahead of others.
#
# Products like Montana and Velo, although generating revenue, showed comparatively lower profitability, indicating opportunities for promotion or bundling.
#
# 4) Segment Insights:
#
# The ***Government segment dominated*** both ***sales and profitability.
#
# Channel Partners and Midmarket showed moderate performance; custom strategies may be needed for better conversion.
#
# 5) Discount & Profit Correlation:
#
# A moderate ***negative correlation*** observed between Discount and Profit (–0.51) suggests ***excessive discounting*** could be ***hurting profitability***.
#
# 6) Category & Bundling Opportunities:
#
# Products with high sales but lower margins (e.g., Carretera, Montana) are good candidates for bundling with top performers like Paseo to boost overall order value
